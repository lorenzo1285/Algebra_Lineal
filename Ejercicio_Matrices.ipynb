# %% [markdown]
# <a href="https://colab.research.google.com/github/lorenzo1285/Algebra_lineal/blob/main/Ejercicio_Matrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# ![imagen_2022-03-10_151431.png](data:image/png;base64,...)

# %%
a = np.array([[1, 4, 7], [2, 5, 8], [3,6,9]])
b = np.array([[1,-1,2], [2,-1,2], [3,-3,0]])

# %%
# a) A+B
a + b
# Out:
# array([[ 2,  3,  9],
#        [ 4,  4, 10],
#        [ 6,  3,  9]])

# %%
# b) B - A
b-a
# Out:
# array([[ 0, -5, -5],
#        [ 0, -6, -6],
#        [ 0, -9, -9]])

# %%
# c) A * B
a @ b
# Out:
# array([[ 30, -26,  10],
#        [ 36, -31,  14],
#        [ 42, -36,  18]])

# %%
# d) B * A
b @ a
# Out:
# array([[ 5, 11, 17],
#        [ 6, 15, 24],
#        [-3, -3, -3]])

# %% [markdown]
# ![imagen_2022-03-10_154709.png](data:image/png;base64,...)

# %%
a_1 = np.array([[1,3,-1], [1,2,8], [2,2,3]])
b_1 = np.array([[2,3,0], [2,-1,5], [1,1,10]])
c_1 = np.array([[1,3,-1], [2,-2,1], [2,3,4]])

# %%
# a) A + B + C
a_1 +b_1 +c_1
# Out:
# array([[ 4,  9, -2],
#        [ 5, -1, 14],
#        [ 5,  6, 17]])

# %%
# b) A -2C + 3B
a_1 -2*c_1 +3*b_1
# Out:
# array([[ 5,  6,  1],
#        [ 3,  3, 21],
#        [ 1, -1, 25]])

# %%
# c) 2(A -3B) -2C
2*a_1 -6*b_1 -2*c_1
# Out:
# array([[-12, -18,   0],
#        [-14,  14, -16],
#        [ -6,  -8, -62]])

# %%
# d) A^t -2B^t
a_1.T -2*b_1.T
# Out:
# array([[ -3,  -3,   0],
#        [ -3,   4,   0],
#        [ -1,  -2, -17]])

# %%
#e) A*B
a_1 @ b_1
# Out:
# array([[ 7, -1,  5],
#        [14,  9, 90],
#        [11,  7, 40]])

# %%
#f) B*A
b_1 @ a_1
# Out:
# array([[ 5, 12, 22],
#        [11, 14,  5],
#        [22, 25, 37]])

# %%
#g) (A + B)*C
(a_1 + b_1)*c_1
# Out:
# array([[ 3, 18,  1],
#        [ 6, -2, 13],
#        [ 6,  9, 52]])
